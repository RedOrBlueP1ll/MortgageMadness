# %%
from sentence_transformers import SentenceTransformer

# %%
query = "this is a query"

# %%
model = SentenceTransformer("/Users/wangyangwu/Documents/Sentence_transformers/saved_models/fine_tuned_model_256")

# %%
query_tensor = model.encode(query, convert_to_numpy=True)

# %%
query_tensor
# Out:
# array([-0.05396656, -0.2275018 , -0.2934802 ,  0.40602374,  0.38283178,
#         0.19931097,  0.10581603,  0.34060848,  0.14206865, -0.0262893 ,
#         0.18898834, -0.19693846, -0.00999895, -0.02408733,  0.24042232,
#        -0.02518067, -0.06278729,  0.10313947,  0.42326108, -0.13807704,
#        -0.11990705, -0.43223926,  0.132267  , -0.01886814, -0.04782157,
#        -0.3625345 ,  0.37404612, -0.2144712 , -0.1411491 ,  0.21684791,
#        -0.10374617,  0.18353146,  0.3646148 , -0.20050155, -0.12956491,
#        -0.17879602,  0.42510045,  0.25098908,  0.3178462 ,  0.20345792,
#        -0.11150631,  0.25106147, -0.03505121, -0.03786957,  0.096173  ,
#        -0.1071808 , -0.03152909,  0.14243641,  0.30966824, -0.11485159,
#         0.02799538,  0.0060145 , -0.09429289,  0.26204687, -0.20725773,
#         0.10970869,  0.10857539,  0.14487123, -0.13017616,  0.01727747,
#         0.04668963, -0.23571861, -0.14487013, -0.37052557, -0.19617322,
# ...
