# %%
import os
import pandas as pd

# %%
text = pd.read_csv("./Sentence_tensors/sentences_text.csv")

# %%
cluster_tensor = pd.read_csv("./Results_data/dimension_384/cl_art_ten_dim384_clus25.csv")

# %%
text_cluster_tensor = pd.concat([text, cluster_tensor], axis=1)

# %%
text_cluster_tensor = text_cluster_tensor.drop(["Unnamed: 0"],axis=1)

# %%
text_cluster_tensor.head()
# Out:
#                                             sentence  cluster  article  \
# 0  We use certain terms in the mortgage deed and ...        2        1
# 1                Here we explain what we mean by it.        2        1
# 2  Obvion: Obvion N.V., the lender that provides ...       15        1
# 3  In these terms and conditions, “you” always re...       15        1
# 4                               Is that more people?       24        1
#
#           0         1         2         3         4         5         6  ...  \
# 0 -0.332179  0.337029 -0.110563 -0.082152 -0.019232 -0.086106 -0.000769  ...
# 1 -0.016433 -0.114031  0.144419  0.074840  0.012719 -0.111723 -0.008909  ...
# 2 -0.200202  0.114994  0.204726 -0.086480  0.139478  0.233080 -0.091336  ...
# 3 -0.047410  0.089673  0.193197 -0.120145 -0.077777 -0.018456 -0.129524  ...
# 4 -0.065596  0.103401 -0.219501  0.060086  0.311024 -0.210074  0.111664  ...
#
#         374       375       376       377       378       379       380  \
# ...

# %%
df_list = list()
for i in range(25):
    df_list.append(pd.DataFrame(text_cluster_tensor[text_cluster_tensor["cluster"]==i]["sentence"], columns=["sentence"]))

# %%
for i in range(len(df_list)):
    file_path = "sentence_cluster_"+str(i)
    save_path = 
    df_list[i].to_csv("./Results_data/sentences_in_cluster/cluster_25_dimension_384/sentenes_cluster_10.csv")
