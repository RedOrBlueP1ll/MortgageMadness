# %%
#!pip install easygui
#!pip install tk
#!pip install unidecode
#!python -m spacy download en_core_web_lg

import pandas as pd
import tkinter
from tkinter import filedialog
import os
import sys
os.chdir('C:/Users/ranja/Desktop/DKE/Year 3/Semester 1/Project 3-1/MortgageMadness/AnswerExtraction/')
current_dir = os.getcwd()
sys.path.append(current_dir)
from AnswerRetriever import AnswerRetriever, BulletPointLangVars
import import_ipynb
import wx
import wx.lib.agw.multidirdialog as MDD
import easygui as eg
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ranja\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ranja\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#the second frame with just a regular answer

class Frame2(wx.Frame):
    def __init__(self, question, answer_df):
        super().__init__(None, title='We Have Results', size=(750,500))
        self.answer_df = answer_df
        self.question = question
        panel = Panel2(self, question)
        self.Show()   
        
class Panel2(wx.Panel):  
    def __init__(self, parent, question):
        super().__init__(parent)
        self.question = question
        self.setFeatures() 
        
    def setFeatures(self):
        font = wx.SystemSettings.GetFont(wx.SYS_SYSTEM_FONT)
        font.SetPointSize(7) 
        
        vbox_main = wx.BoxSizer(wx.VERTICAL)
        hbox_question = wx.BoxSizer(wx.HORIZONTAL)
        hbox_answer = wx.BoxSizer(wx.HORIZONTAL)
        hbox_next = wx.BoxSizer(wx.HORIZONTAL)
        
        question_label = wx.StaticText(self, label='Your Question: ')
        question_label.SetFont(font)
        question_text = wx.StaticText(self, label=self.question)
        hbox_question.Add(question_label, flag=wx.TOP, border=10)
        hbox_question.Add(question_text, flag=wx.LEFT|wx.TOP, border=10)       
        
        answer_label = wx.StaticText(self, label='The answer we found: ')
        answer_label.SetFont(font)
        answer_text = wx.TextCtrl(self, size=(500,100), value = "Answer", style = wx.TE_READONLY | wx.TE_LEFT ) 
        hbox_answer.Add(answer_label, flag=wx.TOP, border=10)
        hbox_answer.Add(answer_text, flag=wx.TOP|wx.LEFT, border=10)
        
        satisfaction_label = wx.StaticText(self, label='Are you satisfied with the answer?')
        satisfaction_label.SetFont(font)
        
        label_list = ['Yes', 'Not entirely', 'No']
        satisfaction_radiobox = wx.RadioBox(self, choices = label_list,
         majorDimension = 1, style = wx.RA_SPECIFY_ROWS) 
        
        next_answer_button = wx.Button(self, label='Next Answer',  size=(150,20))
        next_answer_button.Bind(wx.EVT_BUTTON, self.on_next_answer_button)
        start_over_button = wx.Button(self, label='Start Over',  size=(150,20))
        start_over_button.Bind(wx.EVT_BUTTON, self.on_start_over_button)
        hbox_next.Add(next_answer_button, flag=wx.TOP, border=10)
        hbox_next.Add(start_over_button, flag=wx.TOP|wx.LEFT, border=10)
        
        
        vbox_main.Add(hbox_question, flag=wx.ALL|wx.EXPAND, border=10)
        vbox_main.Add(hbox_answer, flag=wx.ALL|wx.EXPAND, border=10)
        vbox_main.Add(satisfaction_label, flag=wx.LEFT|wx.EXPAND, border=265)
        vbox_main.Add(satisfaction_radiobox, flag=wx.LEFT, border=260)
        vbox_main.Add(hbox_next, flag=wx.LEFT, border=225)
        
        self.SetSizer(vbox_main)
        
    def on_start_over_button(self, event):
        global frame
        frame.Close()
        frame = Frame1()
        
    def on_next_answer_button(self, event):
        global frame
        frame.Close()
        frame = Frame1()

# %%
#the third frame with comparison too

class Frame3(wx.Frame):
    def __init__(self, question, answer_df):
        super().__init__(None, title='We Have Results', size=(750,500))
        self.answer_df = answer_df
        self.question = question
        panel = Panel3(self, question)
        self.Show()   
        
class Panel3(wx.Panel):  
    def __init__(self, parent, question):
        super().__init__(parent)
        self.question = question
        self.setFeatures() 
        
    def setFeatures(self):
        font = wx.SystemSettings.GetFont(wx.SYS_SYSTEM_FONT)
        font.SetPointSize(7) 
        
        vbox_main = wx.BoxSizer(wx.VERTICAL)
        hbox_question = wx.BoxSizer(wx.HORIZONTAL)
        hbox_answer = wx.BoxSizer(wx.HORIZONTAL)
        hbox_next = wx.BoxSizer(wx.HORIZONTAL)
        
        question_label = wx.StaticText(self, label='Your Question: ')
        question_label.SetFont(font)
        question_text = wx.StaticText(self, label=self.question)
        hbox_question.Add(question_label, flag=wx.TOP, border=10)
        hbox_question.Add(question_text, flag=wx.LEFT|wx.TOP, border=10)       
        
        answer_label = wx.StaticText(self, label='The answer we found: ')
        answer_label.SetFont(font)
        answer_text = wx.TextCtrl(self, size=(500,100), value = "Answer", style = wx.TE_READONLY | wx.TE_LEFT ) 
        hbox_answer.Add(answer_label, flag=wx.TOP, border=10)
        hbox_answer.Add(answer_text, flag=wx.TOP|wx.LEFT, border=10)
        
        satisfaction_label = wx.StaticText(self, label='Are you satisfied with the answer?')
        satisfaction_label.SetFont(font)
        
        label_list = ['Yes', 'Not entirely', 'No']
        satisfaction_radiobox = wx.RadioBox(self, choices = label_list,
         majorDimension = 1, style = wx.RA_SPECIFY_ROWS) 
        
        
        next_answer_button = wx.Button(self, label='Next Answer',  size=(150,20))
        next_answer_button.Bind(wx.EVT_BUTTON, self.on_next_answer_button)
        start_over_button = wx.Button(self, label='Start Over',  size=(150,20))
        start_over_button.Bind(wx.EVT_BUTTON, self.on_start_over_button)
        hbox_next.Add(next_answer_button, flag=wx.TOP, border=10)
        hbox_next.Add(start_over_button, flag=wx.TOP|wx.LEFT, border=10)
        
        vbox_main.Add(hbox_question, flag=wx.ALL|wx.EXPAND, border=10)
        vbox_main.Add(hbox_answer, flag=wx.ALL|wx.EXPAND, border=10)
        vbox_main.Add(satisfaction_label, flag=wx.LEFT|wx.EXPAND, border=265)
        vbox_main.Add(satisfaction_radiobox, flag=wx.LEFT, border=260)
        vbox_main.Add(hbox_next, flag=wx.LEFT, border=225)
        
        self.SetSizer(vbox_main)
        
    def on_start_over_button(self, event):
        global frame
        frame.Close()
        frame = Frame1()
        
    def on_next_answer_button(self, event):
        global frame
        frame.Close()
        frame = Frame1()

# %%
#frame 1 which opens and allows you to choose documents/ ask questions

wildcard = "PDF AND DOCX FILES (*.pdf;*.docx;*.txt)|*.pdf;*.docx;*.txt"
target_documents = [] #can change this if only one target document is allowed
other_documents = [] 
question_box_1 = ''
question_box_2 = ''
frame = ''
mainpath = ''


class Panel1(wx.Panel):  
    def __init__(self, parent):
        self.question = ''
        self.keyArticle = ''
        filepath = os.path.abspath("GUI.ipynb")
        mainpath = os.path.dirname(filepath)
        print(os.path.dirname(mainpath))
        super().__init__(parent)
        self.setFeatures() 
        
    def setFeatures(self):
        font = wx.SystemSettings.GetFont(wx.SYS_SYSTEM_FONT)
        font.SetPointSize(7) 
        vbox_main = wx.BoxSizer(wx.VERTICAL)
        
        vbox_11 = wx.BoxSizer(wx.VERTICAL)
        vbox_12 = wx.BoxSizer(wx.VERTICAL)
        hbox_11 = wx.BoxSizer(wx.HORIZONTAL)
        hbox_12 = wx.BoxSizer(wx.HORIZONTAL)
    
        basic_label = wx.StaticText(self, label='Basic')
        basic_label.SetFont(font)
        hbox_11.Add(basic_label, flag=wx.LEFT|wx.EXPAND, border=340)
        
        upload_button_1 = wx.Button(self, size=(200,50), label='Upload Document')
        upload_button_1.Bind(wx.EVT_BUTTON, self.on_upload_button)
        format_1_label = wx.StaticText(self, label='*Format: PDF/docx/txt')
        format_1_label.SetFont(font)
        vbox_11.Add(upload_button_1, flag=wx.LEFT, border=80)
        vbox_11.Add(format_1_label, flag=wx.LEFT, border=80)
        hbox_12.Add(vbox_11, flag=wx.EXPAND)
        
        global question_box_1
        question_box_1 = wx.TextCtrl(self, size=(350,100), style=wx.TE_MULTILINE)
        question_box_1.SetValue("Enter your Question here.")
        self.question = question_box_1.GetValue()
        search_button_1 = wx.Button(self, label='Search', size=(100,20))
        search_button_1.Bind(wx.EVT_BUTTON, self.on_search_button_1)
        vbox_12.Add(question_box_1, flag=wx.EXPAND|wx.LEFT, border=50)
        vbox_12.Add(search_button_1, flag=wx.LEFT, border=50)
        hbox_12.Add(vbox_12, flag=wx.LEFT|wx.EXPAND, border=10)
        
        vbox_main.Add(hbox_11, flag=wx.ALL, border=5)
        vbox_main.Add(-1, 10)
        vbox_main.Add(hbox_12, flag=wx.ALL|wx.EXPAND, border=10)
        vbox_main.Add(-1, 10)
        
        vbox_21 = wx.BoxSizer(wx.VERTICAL)
        vbox_22 = wx.BoxSizer(wx.VERTICAL)
        hbox_21 = wx.BoxSizer(wx.HORIZONTAL)
        hbox_22 = wx.BoxSizer(wx.HORIZONTAL)

        advanced_label = wx.StaticText(self, label='Advanced')
        advanced_label.SetFont(font)
        hbox_21.Add(advanced_label, flag=wx.LEFT|wx.EXPAND, border=340)

        upload_2_target_button = wx.Button(self, size=(200,50), label='Upload Target Document')
        upload_2_target_button.Bind(wx.EVT_BUTTON, self.on_upload_button)
        upload_2_other_button = wx.Button(self, size=(200,50), label='Upload Other Document(s)')
        upload_2_other_button.Bind(wx.EVT_BUTTON, self.on_upload_button)
        format_2_label = wx.StaticText(self, label='*Format: PDF/docx/txt')
        format_2_label.SetFont(font)
        vbox_21.Add(upload_2_target_button, flag=wx.LEFT, border=80)
        vbox_21.Add(upload_2_other_button, flag=wx.LEFT, border=80)
        vbox_21.Add(format_2_label, flag=wx.LEFT, border=80)
        hbox_22.Add(vbox_21, flag=wx.EXPAND)

        global question_box_2
        question_box_2 = wx.TextCtrl(self, size=(350,100), style=wx.TE_MULTILINE)
        question_box_2.SetValue("Enter your Question here.")
        #self.question = question_box_2.GetValue()
        search_button_2 = wx.Button(self, label='Search and Compare',  size=(150,20))
        search_button_2.Bind(wx.EVT_BUTTON, self.on_search_button_2)
        vbox_22.Add(question_box_2, flag=wx.EXPAND|wx.LEFT, border=50)
        vbox_22.Add(search_button_2, flag=wx.LEFT, border=50)
        hbox_22.Add(vbox_22, flag=wx.LEFT|wx.EXPAND, border=10)

        vbox_main.Add(hbox_21, flag=wx.ALL, border=5)
        vbox_main.Add(hbox_22, flag=wx.ALL|wx.EXPAND, border=10)
        
        self.SetSizer(vbox_main)
        
    def on_search_button_1(self, event):
        #ArticleExtractor.articleDict = createArticleDict(target_documents)
        self.question = "What information regarding the colateral is Obvion entitled to?"
        self.keyArticle = '''1 If Obvion proceeds to the forced sale of the collateral, Obvion has the choice
        between public sale (via a notary to be designated by it) and private sale
        with the approval of the preliminary relief judge of the court.
        2. In the event of a forced sale, Obvion is authorized:
        a. to subdivide and/or subdivide the collateral into apartment rights;
        b. to sell the collateral in parts;
        c. sell multiple collateral together;
        d. establish auction or sale conditions;
        e. to establish easements and/or qualitative obligations;
        f. to exercise all rights under the purchase agreement, insofar as the law opposes this
        not resist;
        g. to postpone or cancel a sale.
        3. The mortgagor is obliged:
        a. all desired information, data, documents and evidence about the collateral
        to be handed over to the notary in charge of the sale. Or to the
        preliminary relief judge of the court to whom a request for approval of a
        private sale has been submitted.
        b. to enable interested parties to view the collateral at a location to be determined by Obvion
        set days and times;
        c. in the case of public or private sale, the collateral before the commencement of
        the auction (public sale) or before the date of the notarial deed of transfer
        (private sale) completely and at the free disposal of the buyer
        set. The costs of this will be borne by the mortgagor.
        4. If Obvion also has a right of pledge on movable property that is intended to hold the collateral
        on which the mortgage right is established, Obvion may use the pledged
        sell the goods and the collateral together in accordance with the rules that apply to the law of
        mortgage.
        5. Obvion reduces the debts secured by the right of mortgage with the
        proceeds of the forced sale. Obvion is authorized to determine which debts are
        the yield are reduced and also the order in which and the extent and manner in which
        it happens.
        '''
        #add the starter for the cluster methods. we have to link the clustering and the IR systems.
        
        ar = AnswerRetriever(self.question, self.keyArticle)
        #answer_df = ar.extractAnswer()
        #display(answer_df)
        answer_df = pd.DataFrame()
        global frame
        frame.Close()
        frame = Frame2(self.question, answer_df)
        
        
    def on_search_button_2(self, event):
        #articleDict = createArticleDict(target_documents)
        self.question = question_box_2.GetValue()
        self.keyArticle = '''1 If Obvion proceeds to the forced sale of the collateral, Obvion has the choice
        between public sale (via a notary to be designated by it) and private sale
        with the approval of the preliminary relief judge of the court.
        2. In the event of a forced sale, Obvion is authorized:
        a. to subdivide and/or subdivide the collateral into apartment rights;
        b. to sell the collateral in parts;
        c. sell multiple collateral together;
        d. establish auction or sale conditions;
        e. to establish easements and/or qualitative obligations;
        f. to exercise all rights under the purchase agreement, insofar as the law opposes this
        not resist;
        g. to postpone or cancel a sale.
        3. The mortgagor is obliged:
        a. all desired information, data, documents and evidence about the collateral
        to be handed over to the notary in charge of the sale. Or to the
        preliminary relief judge of the court to whom a request for approval of a
        private sale has been submitted.
        b. to enable interested parties to view the collateral at a location to be determined by Obvion
        set days and times;
        c. in the case of public or private sale, the collateral before the commencement of
        the auction (public sale) or before the date of the notarial deed of transfer
        (private sale) completely and at the free disposal of the buyer
        set. The costs of this will be borne by the mortgagor.
        4. If Obvion also has a right of pledge on movable property that is intended to hold the collateral
        on which the mortgage right is established, Obvion may use the pledged
        sell the goods and the collateral together in accordance with the rules that apply to the law of
        mortgage.
        5. Obvion reduces the debts secured by the right of mortgage with the
        proceeds of the forced sale. Obvion is authorized to determine which debts are
        the yield are reduced and also the order in which and the extent and manner in which
        it happens.
        '''
        #add the starter for the cluster methods. we have to link the clustering and the IR systems.
        ar = AnswerRetriever(self.question, self.keyArticle)
        answer_df = ar.extractAnswer()
        display(answer_df)
        global frame
        frame.Close()
        frame = Frame3(self.question, answer_df)
     
    def on_upload_button(self, event):
        root = tkinter.Tk()
        root.withdraw()
        file = filedialog.askopenfilename(parent=root,title='Choose File')
        if (file not in target_documents):
            target_documents.append(file)
    
    def on_upload_other_button(self, event):
        file = eg.fileopenbox(msg='Please choose the appropriate document',
                title='Choose File', 
                filetypes='*.pdf;*.docx')
        if (file not in other_documents):
            other_documents.append(file)

        
class Frame1(wx.Frame):
    def __init__(self):
        super().__init__(None, title='Obvion Query System', size=(750,500))
        panel = Panel1(self)
        self.Show()       
        
if __name__ == '__main__':
    app = []
    app = wx.App(redirect=False)
    global frame
    frame = Frame1()
    app.MainLoop()
# Out:
# C:\Users\ranja\Desktop\DKE\Year 3\Semester 1\Project 3-1\MortgageMadness
